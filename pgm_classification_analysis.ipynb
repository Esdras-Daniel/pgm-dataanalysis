# %% [markdown]
# # 0. Imports

# %%
# 1. Lendos os dados
import pandas as pd
from pathlib import Path

# 2. Pré-processamento dos Textos
import numpy as np
import re
import unicodedata

# 3. Levantamento das palavras
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
nltk.download('punkt')

from nltk.util import ngrams
from collections import Counter
from tqdm import tqdm

# 4. Outra Abordagem
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.neural_network import MLPClassifier

from sentence_transformers import SentenceTransformer
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\EsdrasDaniel\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\EsdrasDaniel\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# c:\Users\EsdrasDaniel\anaconda3\Lib\site-packages\sentence_transformers\cross_encoder\CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %% [markdown]
# # 1. Lendo os dados

# %%
path = Path('./data/pgm-dataset-v2.parquet')
df = pd.read_parquet(path)

df.head(3)
# Out:
#   intimacao_conteudo processo_conteudo  \
# 0
# 1
# 2
#
#                                             rstREGEX  \
# 0  [{"diligencia": "intime-se o Município de Nata...
# 1  [{"diligencia": "intimado acerca da obrigação ...
# 2  [{"diligencia": "Decido. Compulsando os autos,...
#
#                                        teorIntimacao  \
# 0  PODER JUDICIÁRIO ESTADO DO RIO GRANDE DO NORTE...
# 1  PODER JUDICIÁRIO DO ESTADO DO RIO GRANDE DO NO...
# 2  PODER JUDICIÁRIO DO ESTADO DO RIO GRANDE DO NO...
#
#                                         intimacaoPJE  \
# 0  {"id": "18612632", "tipoComunicacao": "INT", "...
# 1  {"id": "18629258", "tipoComunicacao": "INT", "...
# 2  {"id": "18629422", "tipoComunicacao": "INT", "...
#
#                                          processoPJE idavisopje  \
# 0  {"Numero": "08387198120248205001", "Competenci...   18612632
# 1  {"Numero": "08464942120228205001", "Competenci...   18629258
# 2  {"Numero": "08954169320228205001", "Competenci...   18629422
#
#                   setordestino Classificacao
# 0        Procuradoria da Sa�de
# 1  Procuradoria Administrativa
# 2                     CARTORIO

# %% [markdown]
# ## 1.1 - Removendo valores nulos

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15984 entries, 0 to 15983
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   intimacao_conteudo  15984 non-null  object
#  1   processo_conteudo   15984 non-null  object
#  2   rstREGEX            15942 non-null  object
#  3   teorIntimacao       15942 non-null  object
#  4   intimacaoPJE        15942 non-null  object
#  5   processoPJE         15942 non-null  object
#  6   idavisopje          15356 non-null  object
#  7   setordestino        15356 non-null  object
#  8   Classificacao       15984 non-null  object
# dtypes: object(9)
# memory usage: 1.1+ MB

# %%
docs_nulos = df.teorIntimacao.isna()

print(f'Temos {docs_nulos.sum()} documentos onde teorIntimação é nulo')
# Out:
# Temos 42 documentos onde teorIntimação é nulo

# %%
# Removendo
df.dropna(axis=0, how='any', inplace=True)

# %% [markdown]
# ## 1.2 - Verificando as Classes

# %%
# Substituindo os valores da coluna 'setordestino'

swap_dict = {
    'DEPARTAMENTO DE C�LCULOS E CONTABILIDADE': 'DEPARTAMENTO DE CALCULOS E CONTABILIDADE',
    'Procuradoria da Sa�de': 'Procuradoria da Saude',
    'SETOR DE ADMINISTRA�?O GERAL': 'SETOR DE ADMINISTRACAO GERAL',
    'Procuradoria de Recupera�?o da D�vida Ativa': 'Procuradoria de Recuperacao da Divida Ativa'
}

df['setordestino'].replace(swap_dict, inplace=True)

# %%
df.setordestino.value_counts().sum()
# Out:
# setordestino
# Procuradoria Administrativa                    4744
# APOIO FISCAL                                   4311
# Procuradoria Fiscal                            2368
# DEPARTAMENTO DE CALCULOS E CONTABILIDADE       1338
# Procuradoria Judicial                           976
# Chefia Administrativa                           657
# Procuradoria da Saude                           443
# Chefia Judicial                                 161
# Chefia Meio Ambiente                            121
# Chefia Patrimonial                              121
# Assessoria - Gabinete                            44
# Procuradoria do Meio Ambiente                    34
# Procuradoria Geral                               22
# CHEFIA FISCAL                                     7
# CARTORIO                                          4
# SETOR DE ADMINISTRACAO GERAL                      2
# Procuradoria de Recuperacao da Divida Ativa       2
# Procuradoria Geral Substituta                     1
# Name: count, dtype: int64

# %% [markdown]
# # 2. Pré-processamento dos Textos

# %%
stop_words_pt = set(stopwords.words('portuguese'))

padroes = ['[^\w\s]',
        'poder judiciario do estado do rio grande do norte',
        'poder judiciario estado do rio grande do norte',
        'poder judiciario do estado rio grande do norte',
        'poder judiciario estado rio grande do norte',
        'normal', 'false',
            'ptbr', 'xnone',
            'poder', 'judiciario',
            'estado', 'rio', 'grande', 'norte',
            'vara execucao fiscal',
            'tributaria natal',
            'praca sete setembro',
            'cidade alta',
            'natalrn', 'cep',
            'rn', 'natal', '5902530',
            'assinado', 'digitalmente',
            'forma lei', 'n1141906',
            'comarca', 'forum fazendario',
            'juiz djanirito souza moura',
            'data registrada sistema',
            '1141906', 'veft', '59025275', 'email',
            'secuniefttj', 'jusbr',
            'telefone', 'whatsapp',
            '36738671',
            'judiciario', 'natalpraca',
            'setembro', 'cidade', '59025300',
            'rio norte', 'forum fazendario',
            'juiz', 'djanirito souza mouro',
            'praca alto', 'natalrn', 'nao',
    ]

def preprocessamento(text):
    if text == None:
        return text
    
    text_tokens = word_tokenize(text, language='portuguese')

    filtered_text = [word for word in text_tokens if word.lower() not in stop_words_pt and len(word) > 2]
    text = ' '.join(filtered_text)

    # Retira acentos e converte o texto para minúsculo
    text = unicodedata.normalize('NFKD', text).encode('ASCII', 'ignore').decode('ASCII').lower()

    # Retira alguns padrões definidos na lista 'padroes'
    for padrao in padroes:
        text = re.sub(padrao, '', text)

    return text

# %%
df['teorIntimacao_clean'] = df['teorIntimacao'].apply(preprocessamento)

df.head(3)
# Out:
#   intimacao_conteudo processo_conteudo  \
# 0
# 1
# 2
#
#                                             rstREGEX  \
# 0  [{"diligencia": "intime-se o Município de Nata...
# 1  [{"diligencia": "intimado acerca da obrigação ...
# 2  [{"diligencia": "Decido. Compulsando os autos,...
#
#                                        teorIntimacao  \
# 0  PODER JUDICIÁRIO ESTADO DO RIO GRANDE DO NORTE...
# 1  PODER JUDICIÁRIO DO ESTADO DO RIO GRANDE DO NO...
# 2  PODER JUDICIÁRIO DO ESTADO DO RIO GRANDE DO NO...
#
#                                         intimacaoPJE  \
# 0  {"id": "18612632", "tipoComunicacao": "INT", "...
# 1  {"id": "18629258", "tipoComunicacao": "INT", "...
# 2  {"id": "18629422", "tipoComunicacao": "INT", "...
#
#                                          processoPJE idavisopje  \
# 0  {"Numero": "08387198120248205001", "Competenci...   18612632
# 1  {"Numero": "08464942120228205001", "Competenci...   18629258
# 2  {"Numero": "08954169320228205001", "Competenci...   18629422
#
#                   setordestino Classificacao  \
# 0        Procuradoria da Saude
# 1  Procuradoria Administrativa
# 2                     CARTORIO
#
#                                  teorIntimacao_clean
# 0        vara infancia juventude   processo no083...
# 1       3o ado fazenda publica   processo 0846494...
# 2       3a  ac forum seabra fagundes 315 rua dout...

# %% [markdown]
# # 3. Levantamento dos termos

# %%
def count_up_to_n_grams(corpus, n=7):
    """
    Retorna um dicionário com a contagem dos n_gramas até n de um corpus
    """
    n_grams_count = dict()

    i = 1
    while i <= n:
        for text in tqdm(corpus):
            n_gramas = ngrams(text.split(), i)
            counter = Counter(n_gramas)

            for key, value in counter.items():
                key = ' '.join(key)
                if key in n_grams_count:
                    n_grams_count[key] += value
                else:
                    n_grams_count[key] = value
        i += 1


    return dict(sorted(n_grams_count.items(), key=lambda item: item[1], reverse=True))

# %%
result_dict = count_up_to_n_grams(df['teorIntimacao_clean'], n=5)
# Out:
# 100%|██████████| 15356/15356 [00:04<00:00, 3328.40it/s]
# 100%|██████████| 15356/15356 [00:07<00:00, 2107.56it/s]
# 100%|██████████| 15356/15356 [00:08<00:00, 1866.07it/s]
# 100%|██████████| 15356/15356 [00:09<00:00, 1681.74it/s]
# 100%|██████████| 15356/15356 [00:09<00:00, 1654.41it/s]

# %%
len(result_dict)
# Out:
# 5013680

# %%
result_dict

# %% [markdown]
# # 4. Outra Abordagem

# %% [markdown]
# ## 4.1 - Balanceamento das Classes

# %% [markdown]
# ### 4.1.1 - Removendo classes que possuem pouquíssimos exemplos

# %%
# Recuperando as classes
classes = df['setordestino'].unique().tolist()

# Classes que vamos desconsiderar (haviam < 10 textos)
classes_to_disconsider = ('Procuradoria Geral Substituta', 'Procuradoria de Recuperacao da Divida Ativa',
                          'SETOR DE ADMINISTRACAO GERAL', 'CARTORIO', 'CHEFIA FISCAL')

classes = [classe for classe in classes if classe not in classes_to_disconsider]

# %% [markdown]
# ### 4.1.2 - Recuperando um DataFrame apenas com as classes escolhidas

# %%
new_df = df[df['setordestino'].isin(classes)]

# %% [markdown]
# ### 4.1.3 - Downsampling e Upsampling

# %%
def ajustar_amostras(df, classes, n_docs):
    """
    Ajusta o número de amostras (upsampling ou downsampling) para cada classe em um DataFrame.
    
    Parâmetros:
    - df (pd.DataFrame): DataFrame original.
    - classes (str): Nome da coluna que contém as classes.
    - n_docs (int): Número desejado de documentos por classe.
    
    Retorno:
    - pd.DataFrame: DataFrame ajustado com a quantidade especificada de documentos por classe.
    """
    def ajustar_classe(grupo):
        if len(grupo) > n_docs:
            # Downsampling
            return grupo.sample(n_docs, random_state=42)
        else:
            # Upsampling
            return grupo.sample(n_docs, replace=True, random_state=42)
    
    return df.groupby(classes).apply(ajustar_classe).reset_index(drop=True)

df_ajustado = ajustar_amostras(new_df, 'setordestino', n_docs=500)

# %%
df_ajustado['setordestino'].value_counts()
# Out:
# setordestino
# APOIO FISCAL                                500
# Assessoria - Gabinete                       500
# Chefia Administrativa                       500
# Chefia Judicial                             500
# Chefia Meio Ambiente                        500
# Chefia Patrimonial                          500
# DEPARTAMENTO DE CALCULOS E CONTABILIDADE    500
# Procuradoria Administrativa                 500
# Procuradoria Fiscal                         500
# Procuradoria Geral                          500
# Procuradoria Judicial                       500
# Procuradoria da Saude                       500
# Procuradoria do Meio Ambiente               500
# Name: count, dtype: int64

# %% [markdown]
# ## 4.2 - Train Test Split

# %%
X = df_ajustado['teorIntimacao_clean'].to_numpy()
y = df_ajustado['setordestino'].to_numpy()

X_train_text, X_test_text, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# ## 4.3 - Feature Extraction

# %%
tfidf_vectorizer = TfidfVectorizer(min_df=0.005, ngram_range=(1,2))

# Fazendo o fitting nos dados de treinamento apenas e vetorizando-os
X_train = tfidf_vectorizer.fit_transform(X_train_text)

# Fazendo a vetorização dos dados de teste
X_test = tfidf_vectorizer.transform(X_test_text)

print(f'Shape do trainamento: {X_train.shape}')
print(f'Shape do teste: {X_test.shape}')
# Out:
# Shape do trainamento: (4550, 15298)
# Shape do teste: (1950, 15298)

# %% [markdown]
# ## 4.4 - Técnicas de Classificação

# %%
def plot_confusion_matrix(y_test, y_pred, class_names):
    # Calcula a matriz de confusão
    cm = confusion_matrix(y_test, y_pred)
    
    # Normaliza a matriz para valores entre 0 e 1
    cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    
    # Cria o gráfico
    plt.figure(figsize=(12, 10))
    plt.imshow(cm_normalized, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title('Matriz de Confusão', fontsize=16)
    plt.colorbar()
    
    # Adiciona rótulos
    tick_marks = np.arange(len(class_names))
    plt.xticks(tick_marks, class_names, rotation=45, fontsize=6)
    plt.yticks(tick_marks, class_names, fontsize=6)
    
    # Adiciona os valores na matriz
    thresh = cm_normalized.max() / 2.
    for i, j in np.ndindex(cm_normalized.shape):
        plt.text(j, i, f'{cm[i, j]}\n({cm_normalized[i, j]:.2f})',
                 horizontalalignment="center",
                 color="white" if cm_normalized[i, j] > thresh else "black",
                 fontsize=10)
    
    plt.ylabel('Classe Real', fontsize=14)
    plt.xlabel('Classe Prevista', fontsize=14)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### 4.4.1 - KNN

# %%
knn_clf = KNeighborsClassifier(n_neighbors=7)

knn_clf.fit(X_train, y_train)
y_pred = knn_clf.predict(X_test)

# %%
print(classification_report(y_true=y_test, y_pred=y_pred))
# Out:
#                                           precision    recall  f1-score   support
#
#                             APOIO FISCAL       0.88      0.86      0.87       175
#                    Assessoria - Gabinete       0.71      0.96      0.82       135
#                    Chefia Administrativa       0.42      0.32      0.36       162
#                          Chefia Judicial       0.63      0.71      0.67       149
#                     Chefia Meio Ambiente       0.68      0.88      0.77       136
#                       Chefia Patrimonial       0.66      0.80      0.72       148
# DEPARTAMENTO DE CALCULOS E CONTABILIDADE       0.96      0.93      0.94       161
#              Procuradoria Administrativa       0.50      0.31      0.38       147
#                      Procuradoria Fiscal       0.69      0.65      0.67       141
#                       Procuradoria Geral       0.90      1.00      0.94       146
#                    Procuradoria Judicial       0.51      0.30      0.38       148
#                    Procuradoria da Saude       0.80      0.72      0.76       142
#            Procuradoria do Meio Ambiente       0.82      1.00      0.90       160
#
#                                 accuracy                           0.73      1950
#                                macro avg       0.70      0.73      0.71      1950
#                             weighted avg       0.71      0.73      0.71      1950

# %%
plot_confusion_matrix(y_test=y_test, y_pred=y_pred, class_names=classes)

# %% [markdown]
# ### 4.4.2 - SVM

# %%
svm_clf = SVC()

svm_clf.fit(X_train, y_train)
y_pred = svm_clf.predict(X_test)

# %%
print(classification_report(y_true=y_test, y_pred=y_pred))
# Out:
#                                           precision    recall  f1-score   support
#
#                             APOIO FISCAL       0.94      0.88      0.91       175
#                    Assessoria - Gabinete       0.71      0.90      0.79       135
#                    Chefia Administrativa       0.48      0.25      0.33       162
#                          Chefia Judicial       0.59      0.69      0.63       149
#                     Chefia Meio Ambiente       0.83      0.90      0.86       136
#                       Chefia Patrimonial       0.91      0.71      0.80       148
# DEPARTAMENTO DE CALCULOS E CONTABILIDADE       0.96      0.98      0.97       161
#              Procuradoria Administrativa       0.44      0.39      0.41       147
#                      Procuradoria Fiscal       0.67      0.77      0.72       141
#                       Procuradoria Geral       0.95      1.00      0.97       146
#                    Procuradoria Judicial       0.51      0.49      0.50       148
#                    Procuradoria da Saude       0.86      0.83      0.85       142
#            Procuradoria do Meio Ambiente       0.71      0.89      0.79       160
#
#                                 accuracy                           0.74      1950
#                                macro avg       0.73      0.74      0.73      1950
#                             weighted avg       0.74      0.74      0.73      1950

# %%
plot_confusion_matrix(y_test=y_test, y_pred=y_pred, class_names=classes)

# %% [markdown]
# ### 4.4.3 - Naive Bayes

# %%
nb_clf = MultinomialNB()
nb_clf.fit(X_train, y_train)

y_pred = nb_clf.predict(X_test)

# %%
print(classification_report(y_true=y_test, y_pred=y_pred))
# Out:
#                                           precision    recall  f1-score   support
#
#                             APOIO FISCAL       0.80      0.87      0.83       175
#                    Assessoria - Gabinete       0.56      0.72      0.63       135
#                    Chefia Administrativa       0.38      0.14      0.21       162
#                          Chefia Judicial       0.40      0.60      0.48       149
#                     Chefia Meio Ambiente       0.66      0.57      0.61       136
#                       Chefia Patrimonial       0.81      0.49      0.61       148
# DEPARTAMENTO DE CALCULOS E CONTABILIDADE       0.90      0.98      0.93       161
#              Procuradoria Administrativa       0.49      0.39      0.43       147
#                      Procuradoria Fiscal       0.56      0.60      0.58       141
#                       Procuradoria Geral       0.92      0.84      0.88       146
#                    Procuradoria Judicial       0.41      0.40      0.40       148
#                    Procuradoria da Saude       0.83      0.75      0.79       142
#            Procuradoria do Meio Ambiente       0.49      0.76      0.59       160
#
#                                 accuracy                           0.63      1950
#                                macro avg       0.63      0.62      0.61      1950
#                             weighted avg       0.63      0.63      0.62      1950

# %%
plot_confusion_matrix(y_test=y_test, y_pred=y_pred, class_names=classes)

# %% [markdown]
# ### 4.4.4 - Random Forest

# %%
random_forest_clf = RandomForestClassifier()
random_forest_clf.fit(X_train, y_train)

y_pred = random_forest_clf.predict(X_test)

# %%
print(classification_report(y_true=y_test, y_pred=y_pred))
# Out:
#                                           precision    recall  f1-score   support
#
#                             APOIO FISCAL       0.94      0.86      0.90       175
#                    Assessoria - Gabinete       0.95      0.96      0.96       135
#                    Chefia Administrativa       0.39      0.27      0.32       162
#                          Chefia Judicial       0.73      0.87      0.80       149
#                     Chefia Meio Ambiente       0.84      0.92      0.88       136
#                       Chefia Patrimonial       0.86      0.97      0.91       148
# DEPARTAMENTO DE CALCULOS E CONTABILIDADE       0.97      0.94      0.96       161
#              Procuradoria Administrativa       0.43      0.42      0.43       147
#                      Procuradoria Fiscal       0.67      0.77      0.72       141
#                       Procuradoria Geral       0.95      1.00      0.98       146
#                    Procuradoria Judicial       0.62      0.51      0.56       148
#                    Procuradoria da Saude       0.87      0.87      0.87       142
#            Procuradoria do Meio Ambiente       0.94      1.00      0.97       160
#
#                                 accuracy                           0.79      1950
#                                macro avg       0.78      0.80      0.79      1950
#                             weighted avg       0.78      0.79      0.79      1950

# %%
plot_confusion_matrix(y_test=y_test, y_pred=y_pred, class_names=classes)

# %% [markdown]
# ### 4.4.5 - XGBoost

# %%
sub_dict = {classe: i for i, classe in enumerate(classes)}

y_train_temp = [sub_dict[i] for i in y_train]
y_test_temp = [sub_dict[i] for i in y_test]

xgboost_clf = XGBClassifier()
xgboost_clf.fit(X_train, y_train_temp)

y_pred = xgboost_clf.predict(X_test)

# %%
print(classification_report(y_true=y_test_temp, y_pred=y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.85      0.86       142
#            1       0.40      0.36      0.38       147
#            2       0.92      0.86      0.89       175
#            3       0.69      0.76      0.73       141
#            4       0.96      0.98      0.97       161
#            5       0.74      0.89      0.81       149
#            6       0.45      0.35      0.39       162
#            7       0.71      0.64      0.67       148
#            8       0.91      0.97      0.94       148
#            9       0.90      0.95      0.92       136
#           10       0.96      1.00      0.98       160
#           11       0.95      1.00      0.97       146
#           12       0.94      0.96      0.95       135
#
#     accuracy                           0.81      1950
#    macro avg       0.80      0.81      0.81      1950
# weighted avg       0.80      0.81      0.80      1950

# %%
plot_confusion_matrix(y_test=y_test_temp, y_pred=y_pred, class_names=classes)

# %% [markdown]
# ### 4.4.6 - MLP

# %%
mlp_clf = MLPClassifier(hidden_layer_sizes=(100,100),
                        solver='adam',
                        verbose=True)

mlp_clf.fit(X_train, y_train)
y_pred = mlp_clf.predict(X_test)
# Out:
# Iteration 1, loss = 2.40406799
# Iteration 2, loss = 1.74467646
# Iteration 3, loss = 1.14986139
# Iteration 4, loss = 0.85668648
# Iteration 5, loss = 0.71923572
# Iteration 6, loss = 0.63541688
# Iteration 7, loss = 0.57431426
# Iteration 8, loss = 0.53041077
# Iteration 9, loss = 0.49647551
# Iteration 10, loss = 0.48002435
# Iteration 11, loss = 0.45136846
# Iteration 12, loss = 0.42484820
# Iteration 13, loss = 0.40642689
# Iteration 14, loss = 0.39579183
# Iteration 15, loss = 0.38385624
# Iteration 16, loss = 0.36914004
# Iteration 17, loss = 0.36003237
# Iteration 18, loss = 0.34579395
# Iteration 19, loss = 0.33608578
# Iteration 20, loss = 0.33290726
# Iteration 21, loss = 0.32387561
# Iteration 22, loss = 0.31972600
# Iteration 23, loss = 0.31158407
# Iteration 24, loss = 0.29903597
# Iteration 25, loss = 0.29371297
# Iteration 26, loss = 0.29173715
# Iteration 27, loss = 0.28588774
# Iteration 28, loss = 0.28405140
# Iteration 29, loss = 0.28197480
# Iteration 30, loss = 0.27799455
# Iteration 31, loss = 0.26964911
# Iteration 32, loss = 0.26171102
# Iteration 33, loss = 0.26325936
# Iteration 34, loss = 0.26512851
# Iteration 35, loss = 0.25750235
# Iteration 36, loss = 0.24945624
# Iteration 37, loss = 0.25056339
# Iteration 38, loss = 0.24512147
# Iteration 39, loss = 0.24330833
# Iteration 40, loss = 0.24434491
# Iteration 41, loss = 0.24122938
# Iteration 42, loss = 0.23577822
# Iteration 43, loss = 0.23596068
# Iteration 44, loss = 0.23018804
# Iteration 45, loss = 0.22457906
# Iteration 46, loss = 0.22140979
# Iteration 47, loss = 0.21789325
# Iteration 48, loss = 0.21900343
# Iteration 49, loss = 0.21541734
# Iteration 50, loss = 0.21832183
# Iteration 51, loss = 0.21608793
# Iteration 52, loss = 0.21541708
# Iteration 53, loss = 0.21308585
# Iteration 54, loss = 0.20626022
# Iteration 55, loss = 0.20403541
# Iteration 56, loss = 0.20184755
# Iteration 57, loss = 0.20688215
# Iteration 58, loss = 0.20446709
# Iteration 59, loss = 0.20478046
# Iteration 60, loss = 0.19946186
# Iteration 61, loss = 0.20601290
# Iteration 62, loss = 0.19360018
# Iteration 63, loss = 0.19447124
# Iteration 64, loss = 0.18875051
# Iteration 65, loss = 0.18675308
# Iteration 66, loss = 0.18956015
# Iteration 67, loss = 0.19302476
# Iteration 68, loss = 0.18972883
# Iteration 69, loss = 0.18709189
# Iteration 70, loss = 0.18183135
# Iteration 71, loss = 0.18543476
# Iteration 72, loss = 0.18208838
# Iteration 73, loss = 0.18231532
# Iteration 74, loss = 0.17920019
# Iteration 75, loss = 0.17668952
# Iteration 76, loss = 0.18118944
# Iteration 77, loss = 0.17562270
# Iteration 78, loss = 0.17901972
# Iteration 79, loss = 0.18209632
# Iteration 80, loss = 0.17073647
# Iteration 81, loss = 0.17145565
# Iteration 82, loss = 0.17469724
# Iteration 83, loss = 0.17360041
# Iteration 84, loss = 0.17208390
# Iteration 85, loss = 0.16880305
# Iteration 86, loss = 0.16659228
# Iteration 87, loss = 0.16314042
# Iteration 88, loss = 0.16480797
# Iteration 89, loss = 0.16721206
# Iteration 90, loss = 0.16555330
# Iteration 91, loss = 0.16873950
# Iteration 92, loss = 0.16844662
# Iteration 93, loss = 0.16778263
# Iteration 94, loss = 0.16310456
# Iteration 95, loss = 0.16271230
# Iteration 96, loss = 0.16000654
# Iteration 97, loss = 0.15907954
# Iteration 98, loss = 0.15964822
# Iteration 99, loss = 0.15674811
# Iteration 100, loss = 0.15946739
# Iteration 101, loss = 0.16000689
# Iteration 102, loss = 0.16639583
# Iteration 103, loss = 0.16207937
# Iteration 104, loss = 0.15647243
# Iteration 105, loss = 0.15233770
# Iteration 106, loss = 0.15650238
# Iteration 107, loss = 0.15724614
# Iteration 108, loss = 0.15200663
# Iteration 109, loss = 0.15148950
# Iteration 110, loss = 0.15399024
# Iteration 111, loss = 0.15413830
# Iteration 112, loss = 0.14781601
# Iteration 113, loss = 0.14840203
# Iteration 114, loss = 0.14911381
# Iteration 115, loss = 0.14696764
# Iteration 116, loss = 0.14582398
# Iteration 117, loss = 0.14587537
# Iteration 118, loss = 0.14771230
# Iteration 119, loss = 0.15274562
# Iteration 120, loss = 0.14983771
# Iteration 121, loss = 0.14514366
# Iteration 122, loss = 0.14450893
# Iteration 123, loss = 0.14593692
# Iteration 124, loss = 0.14375479
# Iteration 125, loss = 0.14478598
# Iteration 126, loss = 0.14709903
# Iteration 127, loss = 0.13814237
# Iteration 128, loss = 0.14228721
# Iteration 129, loss = 0.14698783
# Iteration 130, loss = 0.14395213
# Iteration 131, loss = 0.14324425
# Iteration 132, loss = 0.14379894
# Iteration 133, loss = 0.14022006
# Iteration 134, loss = 0.14124647
# Iteration 135, loss = 0.13644308
# Iteration 136, loss = 0.13800880
# Iteration 137, loss = 0.13895693
# Iteration 138, loss = 0.14045504
# Iteration 139, loss = 0.14106196
# Iteration 140, loss = 0.13742057
# Iteration 141, loss = 0.14499600
# Iteration 142, loss = 0.14668967
# Iteration 143, loss = 0.14214945
# Iteration 144, loss = 0.13573240
# Iteration 145, loss = 0.13448002
# Iteration 146, loss = 0.13564054
# Iteration 147, loss = 0.13720919
# Iteration 148, loss = 0.13395863
# Iteration 149, loss = 0.13262094
# Iteration 150, loss = 0.13211782
# Iteration 151, loss = 0.13232771
# Iteration 152, loss = 0.13852863
# Iteration 153, loss = 0.13737633
# Iteration 154, loss = 0.13426861
# Iteration 155, loss = 0.13184899
# Iteration 156, loss = 0.13680271
# Iteration 157, loss = 0.13525497
# Iteration 158, loss = 0.13396890
# Iteration 159, loss = 0.13468497
# Iteration 160, loss = 0.13273693
# Iteration 161, loss = 0.12788642
# Iteration 162, loss = 0.12920668
# Iteration 163, loss = 0.12846554
# Iteration 164, loss = 0.12823639
# Iteration 165, loss = 0.12880670
# Iteration 166, loss = 0.13126324
# Iteration 167, loss = 0.13018473
# Iteration 168, loss = 0.12936511
# Iteration 169, loss = 0.12695780
# Iteration 170, loss = 0.12769319
# Iteration 171, loss = 0.13099964
# Iteration 172, loss = 0.12769415
# Iteration 173, loss = 0.13046637
# Iteration 174, loss = 0.12924507
# Iteration 175, loss = 0.12698154
# Iteration 176, loss = 0.12441812
# Iteration 177, loss = 0.12618187
# Iteration 178, loss = 0.12590482
# Iteration 179, loss = 0.12645500
# Iteration 180, loss = 0.13992606
# Iteration 181, loss = 0.13585455
# Iteration 182, loss = 0.12908166
# Iteration 183, loss = 0.12176259
# Iteration 184, loss = 0.12767639
# Iteration 185, loss = 0.12928836
# Iteration 186, loss = 0.12658069
# Iteration 187, loss = 0.12517288
# Iteration 188, loss = 0.12543456
# Iteration 189, loss = 0.12262085
# Iteration 190, loss = 0.12296168
# Iteration 191, loss = 0.12356786
# Iteration 192, loss = 0.12672411
# Iteration 193, loss = 0.12692648
# Iteration 194, loss = 0.12618096
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.

# %%
print(classification_report(y_true=y_test, y_pred=y_pred))
# Out:
#                                           precision    recall  f1-score   support
#
#                             APOIO FISCAL       0.90      0.88      0.89       175
#                    Assessoria - Gabinete       0.93      0.96      0.95       135
#                    Chefia Administrativa       0.41      0.30      0.34       162
#                          Chefia Judicial       0.71      0.85      0.78       149
#                     Chefia Meio Ambiente       0.86      0.92      0.89       136
#                       Chefia Patrimonial       0.88      0.97      0.92       148
# DEPARTAMENTO DE CALCULOS E CONTABILIDADE       0.95      0.92      0.93       161
#              Procuradoria Administrativa       0.35      0.35      0.35       147
#                      Procuradoria Fiscal       0.70      0.72      0.71       141
#                       Procuradoria Geral       0.97      1.00      0.98       146
#                    Procuradoria Judicial       0.60      0.52      0.56       148
#                    Procuradoria da Saude       0.91      0.89      0.90       142
#            Procuradoria do Meio Ambiente       0.94      1.00      0.97       160
#
#                                 accuracy                           0.79      1950
#                                macro avg       0.78      0.79      0.78      1950
#                             weighted avg       0.78      0.79      0.78      1950

# %%
plot_confusion_matrix(y_test=y_test, y_pred=y_pred, class_names=classes)

# %% [markdown]
# ## 4.5 - Feature Extraction usando BERT

# %%
bert_model = SentenceTransformer('all-MiniLM-L6-v2')

X_train = bert_model.encode(X_train_text, show_progress_bar=True)
X_test = bert_model.encode(X_test_text, show_progress_bar=True)

print(f'Shape das embeddings de treinamento: {X_train.shape}')
print(f'Shape das embeddings de teste: {X_test.shape}')
# Out:
# c:\Users\EsdrasDaniel\anaconda3\Lib\site-packages\transformers\tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Batches:   0%|          | 0/143 [00:00<?, ?it/s]
# Batches:   0%|          | 0/61 [00:00<?, ?it/s]
# Shape das embeddings de treinamento: (4550, 384)
# Shape das embeddings de teste: (1950, 384)

# %% [markdown]
# ### 4.5.1 - Random Forest

# %%
# Random Forest
random_forest_clf = RandomForestClassifier()
random_forest_clf.fit(X_train, y_train)

y_pred = random_forest_clf.predict(X_test)

# %%
print(classification_report(y_true=y_test, y_pred=y_pred))
# Out:
#                                           precision    recall  f1-score   support
#
#                             APOIO FISCAL       0.85      0.85      0.85       175
#                    Assessoria - Gabinete       0.98      0.96      0.97       135
#                    Chefia Administrativa       0.45      0.33      0.38       162
#                          Chefia Judicial       0.82      0.92      0.87       149
#                     Chefia Meio Ambiente       0.90      0.95      0.92       136
#                       Chefia Patrimonial       0.95      0.97      0.96       148
# DEPARTAMENTO DE CALCULOS E CONTABILIDADE       0.97      0.94      0.96       161
#              Procuradoria Administrativa       0.37      0.37      0.37       147
#                      Procuradoria Fiscal       0.62      0.68      0.65       141
#                       Procuradoria Geral       0.95      1.00      0.98       146
#                    Procuradoria Judicial       0.56      0.57      0.56       148
#                    Procuradoria da Saude       0.85      0.83      0.84       142
#            Procuradoria do Meio Ambiente       0.99      1.00      1.00       160
#
#                                 accuracy                           0.80      1950
#                                macro avg       0.79      0.80      0.79      1950
#                             weighted avg       0.79      0.80      0.79      1950

# %%
plot_confusion_matrix(y_test=y_test, y_pred=y_pred, class_names=classes)

# %% [markdown]
# ### 4.5.2 - XGBoost

# %%
# XGBOOST

sub_dict = {classe: i for i, classe in enumerate(classes)}

y_train_temp = [sub_dict[i] for i in y_train]
y_test_temp = [sub_dict[i] for i in y_test]

xgboost_clf = XGBClassifier()
xgboost_clf.fit(X_train, y_train_temp)

y_pred = xgboost_clf.predict(X_test)

# %%
print(classification_report(y_true=y_test_temp, y_pred=y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.85      0.82       142
#            1       0.39      0.39      0.39       147
#            2       0.89      0.82      0.85       175
#            3       0.58      0.70      0.63       141
#            4       0.96      0.96      0.96       161
#            5       0.83      0.93      0.87       149
#            6       0.46      0.33      0.39       162
#            7       0.59      0.52      0.55       148
#            8       0.94      0.97      0.96       148
#            9       0.88      0.92      0.90       136
#           10       0.97      1.00      0.98       160
#           11       0.95      1.00      0.98       146
#           12       0.98      0.96      0.97       135
#
#     accuracy                           0.79      1950
#    macro avg       0.79      0.80      0.79      1950
# weighted avg       0.79      0.79      0.79      1950

# %%
plot_confusion_matrix(y_test=y_test_temp, y_pred=y_pred, class_names=classes)

# %% [markdown]
# ### 4.5.3 - MLP

# %%
mlp_clf = MLPClassifier(hidden_layer_sizes=(100,100),
                        solver='adam',
                        max_iter=500,
                        verbose=True,)

mlp_clf.fit(X_train, y_train)
y_pred = mlp_clf.predict(X_test)
# Out:
# Iteration 1, loss = 2.52929999
# Iteration 2, loss = 2.34818345
# Iteration 3, loss = 2.06602207
# Iteration 4, loss = 1.81043530
# Iteration 5, loss = 1.63775710
# Iteration 6, loss = 1.51568512
# Iteration 7, loss = 1.42267341
# Iteration 8, loss = 1.34290764
# Iteration 9, loss = 1.27805359
# Iteration 10, loss = 1.22344568
# Iteration 11, loss = 1.17718227
# Iteration 12, loss = 1.13879256
# Iteration 13, loss = 1.09704434
# Iteration 14, loss = 1.06409169
# Iteration 15, loss = 1.03554610
# Iteration 16, loss = 1.01152348
# Iteration 17, loss = 0.98232418
# Iteration 18, loss = 0.95584029
# Iteration 19, loss = 0.93927189
# Iteration 20, loss = 0.92457240
# Iteration 21, loss = 0.91066021
# Iteration 22, loss = 0.89073980
# Iteration 23, loss = 0.87253118
# Iteration 24, loss = 0.86354760
# Iteration 25, loss = 0.84848253
# Iteration 26, loss = 0.83416577
# Iteration 27, loss = 0.82328205
# Iteration 28, loss = 0.80745793
# Iteration 29, loss = 0.80099704
# Iteration 30, loss = 0.78719834
# Iteration 31, loss = 0.77837455
# Iteration 32, loss = 0.76644932
# Iteration 33, loss = 0.76265100
# Iteration 34, loss = 0.75568831
# Iteration 35, loss = 0.74299731
# Iteration 36, loss = 0.73877970
# Iteration 37, loss = 0.73175669
# Iteration 38, loss = 0.71913788
# Iteration 39, loss = 0.71199681
# Iteration 40, loss = 0.70419592
# Iteration 41, loss = 0.70010980
# Iteration 42, loss = 0.68953970
# Iteration 43, loss = 0.68474553
# Iteration 44, loss = 0.68162033
# Iteration 45, loss = 0.67587038
# Iteration 46, loss = 0.66535879
# Iteration 47, loss = 0.66600249
# Iteration 48, loss = 0.66204860
# Iteration 49, loss = 0.65117609
# Iteration 50, loss = 0.64598970
# Iteration 51, loss = 0.63770035
# Iteration 52, loss = 0.63602882
# Iteration 53, loss = 0.63079564
# Iteration 54, loss = 0.61991740
# Iteration 55, loss = 0.61416272
# Iteration 56, loss = 0.61083924
# Iteration 57, loss = 0.60988480
# Iteration 58, loss = 0.60902106
# Iteration 59, loss = 0.60057505
# Iteration 60, loss = 0.59484523
# Iteration 61, loss = 0.59062269
# Iteration 62, loss = 0.59085604
# Iteration 63, loss = 0.59017322
# Iteration 64, loss = 0.57950879
# Iteration 65, loss = 0.57772214
# Iteration 66, loss = 0.57227445
# Iteration 67, loss = 0.57311410
# Iteration 68, loss = 0.56427577
# Iteration 69, loss = 0.56282722
# Iteration 70, loss = 0.55172765
# Iteration 71, loss = 0.55024759
# Iteration 72, loss = 0.54178109
# Iteration 73, loss = 0.53648789
# Iteration 74, loss = 0.53655937
# Iteration 75, loss = 0.53255589
# Iteration 76, loss = 0.52870880
# Iteration 77, loss = 0.53232457
# Iteration 78, loss = 0.52346980
# Iteration 79, loss = 0.51757447
# Iteration 80, loss = 0.51610686
# Iteration 81, loss = 0.51730846
# Iteration 82, loss = 0.50693223
# Iteration 83, loss = 0.50666640
# Iteration 84, loss = 0.50476577
# Iteration 85, loss = 0.50267091
# Iteration 86, loss = 0.50281209
# Iteration 87, loss = 0.49665033
# Iteration 88, loss = 0.49290603
# Iteration 89, loss = 0.49360443
# Iteration 90, loss = 0.49599071
# Iteration 91, loss = 0.49151816
# Iteration 92, loss = 0.48195959
# Iteration 93, loss = 0.48459444
# Iteration 94, loss = 0.47537777
# Iteration 95, loss = 0.47482578
# Iteration 96, loss = 0.46866414
# Iteration 97, loss = 0.46346923
# Iteration 98, loss = 0.46579750
# Iteration 99, loss = 0.45957994
# Iteration 100, loss = 0.45924066
# Iteration 101, loss = 0.45925074
# Iteration 102, loss = 0.45687160
# Iteration 103, loss = 0.44960701
# Iteration 104, loss = 0.45007284
# Iteration 105, loss = 0.44730227
# Iteration 106, loss = 0.44502992
# Iteration 107, loss = 0.44128647
# Iteration 108, loss = 0.43643265
# Iteration 109, loss = 0.43614767
# Iteration 110, loss = 0.44146378
# Iteration 111, loss = 0.42954336
# Iteration 112, loss = 0.43107214
# Iteration 113, loss = 0.43524087
# Iteration 114, loss = 0.42508865
# Iteration 115, loss = 0.42549168
# Iteration 116, loss = 0.42284012
# Iteration 117, loss = 0.41627546
# Iteration 118, loss = 0.42124626
# Iteration 119, loss = 0.41823470
# Iteration 120, loss = 0.42087555
# Iteration 121, loss = 0.41421622
# Iteration 122, loss = 0.41274253
# Iteration 123, loss = 0.40648757
# Iteration 124, loss = 0.41092112
# Iteration 125, loss = 0.40492222
# Iteration 126, loss = 0.39844918
# Iteration 127, loss = 0.39729759
# Iteration 128, loss = 0.39875799
# Iteration 129, loss = 0.40421744
# Iteration 130, loss = 0.38951344
# Iteration 131, loss = 0.38574255
# Iteration 132, loss = 0.39502646
# Iteration 133, loss = 0.38873854
# Iteration 134, loss = 0.38455276
# Iteration 135, loss = 0.38697014
# Iteration 136, loss = 0.38856940
# Iteration 137, loss = 0.37914709
# Iteration 138, loss = 0.38215685
# Iteration 139, loss = 0.38062820
# Iteration 140, loss = 0.37543117
# Iteration 141, loss = 0.36944963
# Iteration 142, loss = 0.36998577
# Iteration 143, loss = 0.36780117
# Iteration 144, loss = 0.36559769
# Iteration 145, loss = 0.36440914
# Iteration 146, loss = 0.36470567
# Iteration 147, loss = 0.36211940
# Iteration 148, loss = 0.36608244
# Iteration 149, loss = 0.35903873
# Iteration 150, loss = 0.35470967
# Iteration 151, loss = 0.35356879
# Iteration 152, loss = 0.35156070
# Iteration 153, loss = 0.34839474
# Iteration 154, loss = 0.34645383
# Iteration 155, loss = 0.35095853
# Iteration 156, loss = 0.35100078
# Iteration 157, loss = 0.35578773
# Iteration 158, loss = 0.34826250
# Iteration 159, loss = 0.34997281
# Iteration 160, loss = 0.34041237
# Iteration 161, loss = 0.33573037
# Iteration 162, loss = 0.33750828
# Iteration 163, loss = 0.33622022
# Iteration 164, loss = 0.34151482
# Iteration 165, loss = 0.33711434
# Iteration 166, loss = 0.34170748
# Iteration 167, loss = 0.32799664
# Iteration 168, loss = 0.32760524
# Iteration 169, loss = 0.32951351
# Iteration 170, loss = 0.33107808
# Iteration 171, loss = 0.32715550
# Iteration 172, loss = 0.32569005
# Iteration 173, loss = 0.31989150
# Iteration 174, loss = 0.32123885
# Iteration 175, loss = 0.31814701
# Iteration 176, loss = 0.31709978
# Iteration 177, loss = 0.31660289
# Iteration 178, loss = 0.31472429
# Iteration 179, loss = 0.31423514
# Iteration 180, loss = 0.31346977
# Iteration 181, loss = 0.31268454
# Iteration 182, loss = 0.30912575
# Iteration 183, loss = 0.30694257
# Iteration 184, loss = 0.31211071
# Iteration 185, loss = 0.31243575
# Iteration 186, loss = 0.31029768
# Iteration 187, loss = 0.31169606
# Iteration 188, loss = 0.30486074
# Iteration 189, loss = 0.30524996
# Iteration 190, loss = 0.30612355
# Iteration 191, loss = 0.30207426
# Iteration 192, loss = 0.30500122
# Iteration 193, loss = 0.29406128
# Iteration 194, loss = 0.29873082
# Iteration 195, loss = 0.29930397
# Iteration 196, loss = 0.29816060
# Iteration 197, loss = 0.29314844
# Iteration 198, loss = 0.28628666
# Iteration 199, loss = 0.30126145
# Iteration 200, loss = 0.29722947
# Iteration 201, loss = 0.28837209
# Iteration 202, loss = 0.28877945
# Iteration 203, loss = 0.28629327
# Iteration 204, loss = 0.28218764
# Iteration 205, loss = 0.28206399
# Iteration 206, loss = 0.28539486
# Iteration 207, loss = 0.27684261
# Iteration 208, loss = 0.27831281
# Iteration 209, loss = 0.28082663
# Iteration 210, loss = 0.27707953
# Iteration 211, loss = 0.27688645
# Iteration 212, loss = 0.27448097
# Iteration 213, loss = 0.27681887
# Iteration 214, loss = 0.27118696
# Iteration 215, loss = 0.27152795
# Iteration 216, loss = 0.27470524
# Iteration 217, loss = 0.28397008
# Iteration 218, loss = 0.26682243
# Iteration 219, loss = 0.26613207
# Iteration 220, loss = 0.26757249
# Iteration 221, loss = 0.26732744
# Iteration 222, loss = 0.27313642
# Iteration 223, loss = 0.26506382
# Iteration 224, loss = 0.26634903
# Iteration 225, loss = 0.26467257
# Iteration 226, loss = 0.26734047
# Iteration 227, loss = 0.26980653
# Iteration 228, loss = 0.25582802
# Iteration 229, loss = 0.25761604
# Iteration 230, loss = 0.25853282
# Iteration 231, loss = 0.25972525
# Iteration 232, loss = 0.26029909
# Iteration 233, loss = 0.26614885
# Iteration 234, loss = 0.26671398
# Iteration 235, loss = 0.25686326
# Iteration 236, loss = 0.26599372
# Iteration 237, loss = 0.25424795
# Iteration 238, loss = 0.25347058
# Iteration 239, loss = 0.24898653
# Iteration 240, loss = 0.24724931
# Iteration 241, loss = 0.25455068
# Iteration 242, loss = 0.24872652
# Iteration 243, loss = 0.25214207
# Iteration 244, loss = 0.25034822
# Iteration 245, loss = 0.24819082
# Iteration 246, loss = 0.25660917
# Iteration 247, loss = 0.25300867
# Iteration 248, loss = 0.24134569
# Iteration 249, loss = 0.24629723
# Iteration 250, loss = 0.24367309
# Iteration 251, loss = 0.24284174
# Iteration 252, loss = 0.23502506
# Iteration 253, loss = 0.23297896
# Iteration 254, loss = 0.23850002
# Iteration 255, loss = 0.23774297
# Iteration 256, loss = 0.24039573
# Iteration 257, loss = 0.23514106
# Iteration 258, loss = 0.23236600
# Iteration 259, loss = 0.23079577
# Iteration 260, loss = 0.22892756
# Iteration 261, loss = 0.23204454
# Iteration 262, loss = 0.24169208
# Iteration 263, loss = 0.23551251
# Iteration 264, loss = 0.23279170
# Iteration 265, loss = 0.23121934
# Iteration 266, loss = 0.22267950
# Iteration 267, loss = 0.22433231
# Iteration 268, loss = 0.22523964
# Iteration 269, loss = 0.22375649
# Iteration 270, loss = 0.22433255
# Iteration 271, loss = 0.22471030
# Iteration 272, loss = 0.22026056
# Iteration 273, loss = 0.23311796
# Iteration 274, loss = 0.22953097
# Iteration 275, loss = 0.22552011
# Iteration 276, loss = 0.22518006
# Iteration 277, loss = 0.22000114
# Iteration 278, loss = 0.21886042
# Iteration 279, loss = 0.21680542
# Iteration 280, loss = 0.21955799
# Iteration 281, loss = 0.21639937
# Iteration 282, loss = 0.21446292
# Iteration 283, loss = 0.21381572
# Iteration 284, loss = 0.21435732
# Iteration 285, loss = 0.21151360
# Iteration 286, loss = 0.22074117
# Iteration 287, loss = 0.22698320
# Iteration 288, loss = 0.20838267
# Iteration 289, loss = 0.21900435
# Iteration 290, loss = 0.22133306
# Iteration 291, loss = 0.22040637
# Iteration 292, loss = 0.20720558
# Iteration 293, loss = 0.20787838
# Iteration 294, loss = 0.20378176
# Iteration 295, loss = 0.20841290
# Iteration 296, loss = 0.20196796
# Iteration 297, loss = 0.21224719
# Iteration 298, loss = 0.20217535
# Iteration 299, loss = 0.20597651
# Iteration 300, loss = 0.20431756
# Iteration 301, loss = 0.20529352
# Iteration 302, loss = 0.20376967
# Iteration 303, loss = 0.19844999
# Iteration 304, loss = 0.20072112
# Iteration 305, loss = 0.19838797
# Iteration 306, loss = 0.19816512
# Iteration 307, loss = 0.20188581
# Iteration 308, loss = 0.19521677
# Iteration 309, loss = 0.19880572
# Iteration 310, loss = 0.20463196
# Iteration 311, loss = 0.20647368
# Iteration 312, loss = 0.20641786
# Iteration 313, loss = 0.19885416
# Iteration 314, loss = 0.19612414
# Iteration 315, loss = 0.19893791
# Iteration 316, loss = 0.19167256
# Iteration 317, loss = 0.18777433
# Iteration 318, loss = 0.19666505
# Iteration 319, loss = 0.20471983
# Iteration 320, loss = 0.19294840
# Iteration 321, loss = 0.19304736
# Iteration 322, loss = 0.19213587
# Iteration 323, loss = 0.18882492
# Iteration 324, loss = 0.19197804
# Iteration 325, loss = 0.18643615
# Iteration 326, loss = 0.19080574
# Iteration 327, loss = 0.19132127
# Iteration 328, loss = 0.19317013
# Iteration 329, loss = 0.19071517
# Iteration 330, loss = 0.18652887
# Iteration 331, loss = 0.18323632
# Iteration 332, loss = 0.18646520
# Iteration 333, loss = 0.18550509
# Iteration 334, loss = 0.17788855
# Iteration 335, loss = 0.18537811
# Iteration 336, loss = 0.18395007
# Iteration 337, loss = 0.18513910
# Iteration 338, loss = 0.19342932
# Iteration 339, loss = 0.18529598
# Iteration 340, loss = 0.19113622
# Iteration 341, loss = 0.18237378
# Iteration 342, loss = 0.17898992
# Iteration 343, loss = 0.17628337
# Iteration 344, loss = 0.17609709
# Iteration 345, loss = 0.18364669
# Iteration 346, loss = 0.18281318
# Iteration 347, loss = 0.18360417
# Iteration 348, loss = 0.17562217
# Iteration 349, loss = 0.17714297
# Iteration 350, loss = 0.18149156
# Iteration 351, loss = 0.17435546
# Iteration 352, loss = 0.17515125
# Iteration 353, loss = 0.17382537
# Iteration 354, loss = 0.16795114
# Iteration 355, loss = 0.17146097
# Iteration 356, loss = 0.17261670
# Iteration 357, loss = 0.17406773
# Iteration 358, loss = 0.18102953
# Iteration 359, loss = 0.17620069
# Iteration 360, loss = 0.17033919
# Iteration 361, loss = 0.16786052
# Iteration 362, loss = 0.16988747
# Iteration 363, loss = 0.17035804
# Iteration 364, loss = 0.16374461
# Iteration 365, loss = 0.16879056
# Iteration 366, loss = 0.17267653
# Iteration 367, loss = 0.17657037
# Iteration 368, loss = 0.17424919
# Iteration 369, loss = 0.16782456
# Iteration 370, loss = 0.16480159
# Iteration 371, loss = 0.16843447
# Iteration 372, loss = 0.16793700
# Iteration 373, loss = 0.16270415
# Iteration 374, loss = 0.15894506
# Iteration 375, loss = 0.16381188
# Iteration 376, loss = 0.16876826
# Iteration 377, loss = 0.16541370
# Iteration 378, loss = 0.17262797
# Iteration 379, loss = 0.16596434
# Iteration 380, loss = 0.16336947
# Iteration 381, loss = 0.16312665
# Iteration 382, loss = 0.16134065
# Iteration 383, loss = 0.16232217
# Iteration 384, loss = 0.17113559
# Iteration 385, loss = 0.16302528
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.

# %%
print(classification_report(y_true=y_test, y_pred=y_pred))
# Out:
#                                           precision    recall  f1-score   support
#
#                             APOIO FISCAL       0.89      0.78      0.83       175
#                    Assessoria - Gabinete       0.87      0.96      0.92       135
#                    Chefia Administrativa       0.46      0.40      0.42       162
#                          Chefia Judicial       0.69      0.86      0.76       149
#                     Chefia Meio Ambiente       0.83      0.92      0.87       136
#                       Chefia Patrimonial       0.83      0.98      0.90       148
# DEPARTAMENTO DE CALCULOS E CONTABILIDADE       0.96      0.95      0.96       161
#              Procuradoria Administrativa       0.37      0.28      0.32       147
#                      Procuradoria Fiscal       0.58      0.62      0.60       141
#                       Procuradoria Geral       0.93      1.00      0.96       146
#                    Procuradoria Judicial       0.60      0.33      0.43       148
#                    Procuradoria da Saude       0.72      0.83      0.77       142
#            Procuradoria do Meio Ambiente       0.93      1.00      0.96       160
#
#                                 accuracy                           0.76      1950
#                                macro avg       0.74      0.76      0.75      1950
#                             weighted avg       0.74      0.76      0.75      1950

# %%
plot_confusion_matrix(y_test=y_test, y_pred=y_pred, class_names=classes)
