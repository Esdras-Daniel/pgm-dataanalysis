# %%
import pandas as pd

# %%
path = '../data/raw/pgm-dataset.csv'

df = pd.read_csv(path, sep=',')

# %%
df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        teorTexto  \
# ...
